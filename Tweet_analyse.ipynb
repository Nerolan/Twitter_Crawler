# %%
import pandas as pd

# %%
df = pd.read_csv("hashtag_tweets.csv")

# %%
df.head()
# Out:
#                                               Tweets          User  \
# 0  Every city should do this! Replace cops with m...  rebbyanngray
# 1  Republican attorneys general group launches ra...      afronola
# 2  with info &amp; the sheer number of police rel...   rahne_jones
# 3  Let's live up to the ideal of America! #BlackL...  herbgreen100
# 4  @DailyCaller Seems like most cities currently ...   rockymtndew
#
#          Location  Follower Count  Following Count  Number of Tweets  \
# 0  Washington, DC               4               33                93
# 1            NOLA            1712             2412            162687
# 2    New York, NY            2806              180              1258
# 3             NaN              20              115              1741
# 4         Arizona            1032             1021              1912
#
#   Account Created Date                                Account Description  \
# ...
